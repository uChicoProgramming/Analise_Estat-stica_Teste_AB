# %% [markdown]
# <a href="https://colab.research.google.com/github/uChicoProgramming/Analise_Estat-stica_Teste_AB/blob/main/gittryout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
a = np.array([4,4,4,4])
a
# Out:
# array([4, 4, 4, 4])

# %%
print('oiii')
# Out:
# oiii
